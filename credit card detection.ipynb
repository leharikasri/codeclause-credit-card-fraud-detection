# %% [markdown]
#  <font size="8">Credit Card Fraud Detection</font>.

# %% [markdown]
# <font size="4">Importing the libraries</font>.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
#  <font size="4">Imporing the data</font>

# %%
credit_data = pd.read_csv('C:\\Users\\hp\\Downloads\\archive\creditcard.csv')

# %% [markdown]
#  <font size="4">Data Exploration</font>.

# %%
credit_data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.759061e-12 -8.251130e-13 -9.654937e-13  8.321385e-13
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.649999e-13  4.248366e-13 -3.054600e-13  8.777971e-14 -1.179749e-12
# ...

# %%
credit_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
print(credit_data.columns)
print(credit_data.info())
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
# ...

# %%
fraud=credit_data[credit_data['Class']==1]
valid=credit_data[credit_data['Class']==0]
print("Fraud Cases: {}".format(len(credit_data[credit_data['Class']==1])))
print("Valid Transactions: {}".format(len(credit_data[credit_data['Class']==0])))
# Out:
# Fraud Cases: 492
# Valid Transactions: 284315

# %% [markdown]
#  <font size="4">Handling missing values</font>

# %%
credit_data_missing_columns = (round(((credit_data.isnull().sum()/len(credit_data.index))*100),2).to_frame('null')).sort_values('null', ascending=False)
credit_data_missing_columns
# Out:
#         null
# Time     0.0
# V16      0.0
# Amount   0.0
# V28      0.0
# V27      0.0
# V26      0.0
# V25      0.0
# V24      0.0
# V23      0.0
# V22      0.0
# V21      0.0
# V20      0.0
# V19      0.0
# V18      0.0
# V17      0.0
# V15      0.0
# V1       0.0
# V14      0.0
# V13      0.0
# V12      0.0
# V11      0.0
# V10      0.0
# V9       0.0
# V8       0.0
# V7       0.0
# V6       0.0
# V5       0.0
# V4       0.0
# V3       0.0
# V2       0.0
# Class    0.0

# %% [markdown]
# <font size="4">Data Visualization</font>.

# %%
corr = credit_data.corr()
corr.style.background_gradient()
# Out:
# <style type="text/css">
# #T_783c4_row0_col0, #T_783c4_row1_col1, #T_783c4_row2_col2, #T_783c4_row3_col3, #T_783c4_row4_col4, #T_783c4_row5_col5, #T_783c4_row6_col6, #T_783c4_row7_col7, #T_783c4_row8_col8, #T_783c4_row9_col9, #T_783c4_row10_col10, #T_783c4_row11_col11, #T_783c4_row12_col12, #T_783c4_row13_col13, #T_783c4_row14_col14, #T_783c4_row15_col15, #T_783c4_row16_col16, #T_783c4_row17_col17, #T_783c4_row18_col18, #T_783c4_row19_col19, #T_783c4_row20_col20, #T_783c4_row21_col21, #T_783c4_row22_col22, #T_783c4_row23_col23, #T_783c4_row24_col24, #T_783c4_row25_col25, #T_783c4_row26_col26, #T_783c4_row27_col27, #T_783c4_row28_col28, #T_783c4_row29_col29, #T_783c4_row30_col30 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# ...

# %%
sns.countplot(data = credit_data, x='Class')
plt.title('Number of fraudulent vs non-fraudulent transcations')
plt.show()

# %% [markdown]
# <font size="4">Tain-Test split</font>

# %%
from sklearn.model_selection import train_test_split

# %%
X = credit_data.drop(['Class'], axis=1)

# %%
y = credit_data['Class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=100)

# %% [markdown]
# <font size="4">Analysis</font>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, precision_score, recall_score, f1_score

# %%
X = credit_data.drop('Class', axis=1)
y = credit_data.Class

standard_scaler = StandardScaler()
X = standard_scaler.fit_transform(X)

# %%
models = {
    'Logistic Regression': LogisticRegression(),
}

# %%
print('Result of ML Models are:')
print(' ')

for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    
    
    print(f'{name} Metrics:')
    print(f'Accuracy: {accuracy:.2f}')
    print(f'Precision: {precision:.2f}')
    print(f'Recall: {recall:.2f}')
    print(f'F1-score: {f1:.2f}')
    print(' ')
# Out:
# Result of ML Models are:
#
# Logistic Regression Metrics:
# Accuracy: 1.00
# Precision: 0.66
# Recall: 0.64
# F1-score: 0.65
